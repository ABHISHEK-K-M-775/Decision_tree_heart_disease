# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df['ca'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['ca'].unique()
#
# NameError: name 'df' is not defined

# %%
df['thal'].unique()
# Out:
# array(['3.0', '7.0', '6.0', '?'], dtype=object)

# %% [markdown]
# >both ca and thal have '?' for missing values

# %%
df.loc[(df['ca']=='?')|(df['thal']=='?')]
# Out:
#       age  sex   cp  restbp   chol  fbs  restecg  thalach  exang  oldpeak  \
# 86   53.0  0.0  3.0   128.0  216.0  0.0      2.0    115.0    0.0      0.0
# 165  52.0  1.0  3.0   138.0  223.0  0.0      0.0    169.0    0.0      0.0
# 191  43.0  1.0  4.0   132.0  247.0  1.0      2.0    143.0    1.0      0.1
# 265  52.0  1.0  4.0   128.0  204.0  1.0      0.0    156.0    1.0      1.0
# 286  58.0  1.0  2.0   125.0  220.0  0.0      0.0    144.0    0.0      0.4
# 301  38.0  1.0  3.0   138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  hd
# 86     1.0  0.0    ?   0
# 165    1.0    ?  3.0   0
# 191    2.0    ?  7.0   1
# 265    2.0  0.0    ?   2
# 286    2.0    ?  7.0   0
# 301    1.0    ?  3.0   0

# %% [markdown]
# >since only six samples have missing value that out of 303 samples that's less than 2% so we can drop those samples

# %%
df.drop(df[(df['ca']=='?') | (df['thal']=='?')].index,inplace=True)
